# %%
import PyMieScatt as ps
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
file = "ChaINa2_L_06-05-2002.ascii"
df = pd.read_csv(file,sep='\s+',skiprows=17)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-e9743363dfcb> in <module>
#       1 file = "ChaINa2_L_06-05-2002.ascii"
# ----> 2 df = pd.read_csv(file,sep='\s+',skiprows=17)
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
# ...

# %%
df
# Out:
#      2007.890  4.98035D+00  -7.19437D-05  1.33573D+00  1.40101D-02
# 0     2008.37  4.97916D+00  -5.77122D-05  1.33563D+00  1.40978D-02
# 1     2008.86  4.97795D+00  -5.84386D-05  1.33585D+00  1.40994D-02
# 2     2009.34  4.97676D+00  -7.59671D-05  1.33577D+00  1.39967D-02
# 3     2009.82  4.97557D+00  -6.73179D-05  1.33585D+00  1.40529D-02
# 4     2010.30  4.97438D+00  -6.55139D-05  1.33580D+00  1.40665D-02
# ..        ...          ...           ...          ...          ...
# 392   2197.40  4.55083D+00   2.97692D-04  1.23965D+00  1.53904D-02
# 393   2197.88  4.54984D+00   2.90542D-04  1.23984D+00  1.53566D-02
# 394   2198.36  4.54885D+00   2.98020D-04  1.24003D+00  1.54087D-02
# 395   2198.84  4.54785D+00   3.12714D-04  1.24007D+00  1.54988D-02
# 396   2199.33  4.54684D+00   2.65129D-04  1.24047D+00  1.52333D-02
#
# [397 rows x 5 columns]
